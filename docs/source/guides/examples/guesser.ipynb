# %% [markdown]
# # Guess Scale or Chord from Notes
#
# The music theory encoded in AutoMuse allows for some interesting applications. For example, `automuse.guesser.guess_scale` takes a set of notes, then guesses which scale or chords the notes may be from.
#
# These tools were developed to help with transcription and reharmonisation. This awesome power is now yours to command.
#
# This tutorial covers two functions, `guess_scale` and `guess_chord`.

# %%
import random
random.seed(44313)
from automuse.guesser import guess_scale, guess_chord, tabulate_guess, MatchResult
from automuse.guesser import TEST_SCALES, TEST_SCALES_STANDARD

# %% [markdown]
# Note that `guess` takes two arguments: (a) a set of note names and (b) scales and chords to test against.
#
# The module comes with several options for the latter:
#
# | Option | Included |
# | - | - |
# | `TEST_SCALES_STANDARD` | Major and minor |
# | `TEST_SCALES_MINORS` | Natural, harmonic, and melodic minors |
# | `TEST_SCALES_EXPANDED` | Augmented, diminished, pentatonic, and blues |
# | `TEST_SCALES_EXOTIC` | Whole tone and chromatic scales |
# | `TEST_SCALES_MODES` | From Ionian to Locrian |
# | `TEST_SCALES` | Every scale. Probably has perfect matches for everything. |
# | `TEST_TRIAD_MODES` | Triads |
# | `TEST_SEVENTH_MODES` | Seventh chords |
# | `TEST_CHORDS` | All chords |

# %% [markdown]
# Suppose we hear a melody and identify that it contains $\text{G}$, $\text{E}$, and $\text{C}\#$. To transcribe, reharmonise, or improv from it, we would like to assign it a scale.
#
# To find which scale contains these notes, call `guess_scale` then give the output to `tabulate_guess`.
#
# The result includes a list of possible scales. While several are equally likely, it does give us some interesting information: because many dissonant scales (e.g. Diminished, Locrian) are matched, we may choose to rock it up a little. Blues also looks feasible.

# %%
tabulate_guess(guess_scale(["G", "E", "C#"],
                           TEST_SCALES,
                           match_order="any")[:10],
               tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>Key  </th><th>Mode        </th><th>Matched         </th><th>Unmatched  </th><th>Unused                      </th><th>Check           </th><th>Against                                     </th></tr>\n</thead>\n<tbody>\n<tr><td>C    </td><td>Dim H-W     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;F#&#x27;, &#x27;D#&#x27;, &#x27;C&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;]</td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;D#&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;]</td></tr>\n<tr><td>C#   </td><td>Dim W-H     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D#&#x27;, &#x27;F#&#x27;, &#x27;C&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;]</td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C#&#x27;, &#x27;D#&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;, &#x27;C&#x27;]</td></tr>\n<tr><td>C#   </td><td>Dim H-W     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;G#&#x27;, &#x27;D&#x27;, &#x27;F&#x27;, &#x27;B&#x27;, &#x27;A#&#x27;] </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C#&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;G#&#x27;, &#x27;A#&#x27;, &#x27;B&#x27;] </td></tr>\n<tr><td>C#   </td><td>m (Blues)   </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;B&#x27;, &#x27;F#&#x27;, &#x27;G#&#x27;]           </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C#&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;G#&#x27;, &#x27;B&#x27;]           </td></tr>\n<tr><td>C#   </td><td>Locrian     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C#&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;]       </td></tr>\n<tr><td>D    </td><td>M           </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;]       </td></tr>\n<tr><td>D    </td><td>m (Harmonic)</td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;F&#x27;, &#x27;A#&#x27;, &#x27;A&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;, &#x27;C#&#x27;]       </td></tr>\n<tr><td>D    </td><td>m (Melodic) </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;F&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]        </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;]        </td></tr>\n<tr><td>D    </td><td>Dim W-H     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;G#&#x27;, &#x27;D&#x27;, &#x27;F&#x27;, &#x27;B&#x27;, &#x27;A#&#x27;] </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;G#&#x27;, &#x27;A#&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;] </td></tr>\n<tr><td>D    </td><td>Ionian      </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;,  ...

# %% [markdown]
# ### Refining the Match
#
# You, the musician, are in ultimate control of your creations. You can choose to only match against certain modes, or filter the result:

# %%
tabulate_guess(guess_scale(["G", "E", "C#"],
                           TEST_SCALES_STANDARD,
                           match_order="any")[:5],
               tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>Key  </th><th>Mode  </th><th>Matched         </th><th>Unmatched  </th><th>Unused                      </th><th>Check           </th><th>Against                                </th></tr>\n</thead>\n<tbody>\n<tr><td>D    </td><td>M     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;]  </td></tr>\n<tr><td>B    </td><td>m     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;C#&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;]  </td></tr>\n<tr><td>C    </td><td>M     </td><td>[&#x27;G&#x27;, &#x27;E&#x27;]      </td><td>[&#x27;C#&#x27;]     </td><td>[&#x27;D&#x27;, &#x27;C&#x27;, &#x27;F&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]   </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;]    </td></tr>\n<tr><td>C#   </td><td>m     </td><td>[&#x27;C#&#x27;, &#x27;E&#x27;]     </td><td>[&#x27;G&#x27;]      </td><td>[&#x27;D#&#x27;, &#x27;F#&#x27;, &#x27;G#&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]</td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C#&#x27;, &#x27;D#&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G#&#x27;, &#x27;A&#x27;, &#x27;B&#x27;]</td></tr>\n<tr><td>D    </td><td>m     </td><td>[&#x27;G&#x27;, &#x27;E&#x27;]      </td><td>[&#x27;C#&#x27;]     </td><td>[&#x27;D&#x27;, &#x27;F&#x27;, &#x27;C&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;]  </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;, &#x27;C&#x27;]   </td></tr>\n</tbody>\n</table>'

# %%
match_result: list[MatchResult] =\
    [x for x in guess_scale(["G", "E", "C#"],
                            TEST_SCALES,
                            match_order="any")
     if x.mode == "M"]
tabulate_guess(match_result[:5],
               tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>Key  </th><th>Mode  </th><th>Matched         </th><th>Unmatched  </th><th>Unused                      </th><th>Check           </th><th>Against                                </th></tr>\n</thead>\n<tbody>\n<tr><td>D    </td><td>M     </td><td>[&#x27;C#&#x27;, &#x27;G&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;D&#x27;, &#x27;B&#x27;, &#x27;A&#x27;, &#x27;F#&#x27;]       </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;]  </td></tr>\n<tr><td>C    </td><td>M     </td><td>[&#x27;G&#x27;, &#x27;E&#x27;]      </td><td>[&#x27;C#&#x27;]     </td><td>[&#x27;D&#x27;, &#x27;C&#x27;, &#x27;F&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]   </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;C&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;]    </td></tr>\n<tr><td>E    </td><td>M     </td><td>[&#x27;C#&#x27;, &#x27;E&#x27;]     </td><td>[&#x27;G&#x27;]      </td><td>[&#x27;D#&#x27;, &#x27;F#&#x27;, &#x27;G#&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]</td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;E&#x27;, &#x27;F#&#x27;, &#x27;G#&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C#&#x27;, &#x27;D#&#x27;]</td></tr>\n<tr><td>F    </td><td>M     </td><td>[&#x27;G&#x27;, &#x27;E&#x27;]      </td><td>[&#x27;C#&#x27;]     </td><td>[&#x27;D&#x27;, &#x27;F&#x27;, &#x27;C&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;]  </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;F&#x27;, &#x27;G&#x27;, &#x27;A&#x27;, &#x27;A#&#x27;, &#x27;C&#x27;, &#x27;D&#x27;, &#x27;E&#x27;]   </td></tr>\n<tr><td>G    </td><td>M     </td><td>[&#x27;G&#x27;, &#x27;E&#x27;]      </td><td>[&#x27;C#&#x27;]     </td><td>[&#x27;F#&#x27;, &#x27;D&#x27;, &#x27;C&#x27;, &#x27;B&#x27;, &#x27;A&#x27;]  </td><td>[&#x27;G&#x27;, &#x27;E&#x27;, &#x27;C#&#x27;]</td><td>[&#x27;G&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C&#x27;, &#x27;D&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;]   </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# ### Matching in Order
#
# You might wish to match against a particular progression, there is an option for that. The `match_order` parameter can take one of three values:
#
# * `"any"`, the default: No order required.
#
# * `"order"`: Match notes in order; other notes between matched notes are allowed.
#
# * `"substring"`: Match exact substrings.

# %%
tabulate_guess(guess_scale(["C", "C#", "E"],
                           TEST_SCALES,
                           match_order="substring")[:5],
               tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>Key  </th><th>Mode        </th><th>Matched         </th><th>Unmatched  </th><th>Unused                </th><th>Check           </th><th>Against                               </th></tr>\n</thead>\n<tbody>\n<tr><td>F    </td><td>m (Harmonic)</td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;F&#x27;, &#x27;G&#x27;, &#x27;G#&#x27;, &#x27;A#&#x27;]</td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[&#x27;F&#x27;, &#x27;G&#x27;, &#x27;G#&#x27;, &#x27;A#&#x27;, &#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td></tr>\n<tr><td>F    </td><td>A           </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;F&#x27;, &#x27;G#&#x27;, &#x27;A&#x27;]      </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[&#x27;F&#x27;, &#x27;G#&#x27;, &#x27;A&#x27;, &#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]      </td></tr>\n<tr><td>F#   </td><td>m (Blues)   </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;F#&#x27;, &#x27;A&#x27;, &#x27;B&#x27;]      </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[&#x27;F#&#x27;, &#x27;A&#x27;, &#x27;B&#x27;, &#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]      </td></tr>\n<tr><td>A    </td><td>A           </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;A&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]      </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[&#x27;A&#x27;, &#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]      </td></tr>\n<tr><td>A    </td><td>M (Blues)   </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[]         </td><td>[&#x27;A&#x27;, &#x27;B&#x27;, &#x27;F#&#x27;]      </td><td>[&#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;]</td><td>[&#x27;A&#x27;, &#x27;B&#x27;, &#x27;C&#x27;, &#x27;C#&#x27;, &#x27;E&#x27;, &#x27;F#&#x27;]      </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# ## Match Chords
#
# The function `guess_chord` is a convenience function that matches notes against standard chords.
#
# Suppose that you would like a chord that contains exactly $\text{B}$, $\text{F}$, and $\text{G}\#$. `guess_chord` is able to check these notes against _all_ roman numerals, _all_ modes, and _all_ inversions. Be aware that because the function needs to construct a chord for every combination of these, it takes significantly longer to run.

# %%
tabulate_guess(guess_chord(
    ["B", "F", "G#"],
    orders = [0],
    inversions = list(range(3)),
    match_order="substring")[:10],
    tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>Key  </th><th>Mode         </th><th>Matched         </th><th>Unmatched  </th><th>Unused     </th><th>Check           </th><th>Against              </th></tr>\n</thead>\n<tbody>\n<tr><td>F    </td><td>Dim W-H⁶₄(I) </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[]         </td><td>[]         </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]     </td></tr>\n<tr><td>F    </td><td>Dim H-W⁶₄(I) </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[]         </td><td>[]         </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]     </td></tr>\n<tr><td>F    </td><td>Locrian⁶₄(I) </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[]         </td><td>[]         </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]     </td></tr>\n<tr><td>F    </td><td>Dim W-H⁶(I)  </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;]     </td></tr>\n<tr><td>F    </td><td>Dim W-H⁺(I)  </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;F&#x27;, &#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;]</td></tr>\n<tr><td>F    </td><td>Dim W-H⁺⁶(I) </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;G#&#x27;, &#x27;F&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;, &#x27;F&#x27;]</td></tr>\n<tr><td>F    </td><td>Dim W-H⁺⁶₄(I)</td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td></tr>\n<tr><td>F    </td><td>Dim H-W⁶(I)  </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;]     </td></tr>\n<tr><td>F    </td><td>Dim H-W⁺(I)  </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;F&#x27;, &#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;]</td></tr>\n<tr><td>F    </td><td>Dim H-W⁺⁶(I) </td><td>[&#x27;B&#x27;, &#x27;F&#x27;]      </td><td>[&#x27;G#&#x27;]     </td><td>[&#x27;G#&#x27;, &#x27;F&#x27;]</td><td>[&#x27;B&#x27;, &#x27;F&#x27;, &#x27;G#&#x27;]</td><td>[&#x27;G#&#x27;, &#x27;B&#x27;, &#x27;F&#x27;, &#x27;F&#x27;]</td></tr>\n</tbody>\n</table>'

# %% [markdown]
# It would appear that ... the second inversion of the diminished whole-half scale in $\text{F}$ is a good candidate. Who'd have thought. You can perhaps reharmonise with this information.
